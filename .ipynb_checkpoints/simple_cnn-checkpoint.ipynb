# %% [markdown]
# # 데이터 불러오기

# %%
# 끝자리가 7로 끝나는 데이터만 가져오기
data = open("20240705-171717_DecaWaveAllAccum.log", "r")
data_log = []
i = 0

for line in data:
    if len(line) > 1000:
        data_log.append(line)

# %%
len(data_log)
# Out:
# 3540

# %%
data_log[0][:132]  # 없애야할 부분
# Out:
# 'RX E\x00 WInd(0735), PSC(0449), CE(0000), RSE(0000), HE(0000), STO(0001), FFE(0000), T(7EB4), RSL(-085.1200), FSL(-086.2409), RSMPL(01)'

# %%
processed_data = []

# 데이터 순회
for i in data_log:
    # 알파벳이 포함된 경우
    if any(c.isalpha() for c in i):
        # "RSMPL(01)" 문자열의 위치 찾기
        index = i.find("RSMPL")
        # 해당 위치가 유효한 경우
        if index != -1:
            # "RSMPL(01)"까지의 문자열 제거
            i = i[index + len("RSMPL")+4:]
            processed_data.append(i)
        else:
            # "RSMPL(01)" 문자열이 없는 경우, 원본 데이터 추가
            processed_data.append(i)
    else:
        # 알파벳이 없는 경우, 원본 데이터 추가
        processed_data.append(i)

# 처리된 데이터 출력

# %%
data_log = processed_data
raw_data = []

for i in range(len(data_log)):
    data_sample = [int(x) for x in data_log[i].strip().split(",") if x]
    raw_data.append(data_sample)

# %%
len(raw_data[0])
for i in range(10):
    print(len(raw_data[i]))
# Out:
# 2032
# 1016
# 1016
# 2032
# 1016
# 2032
# 1016
# 1016
# 1016
# 1016

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.clf()
plt.plot(raw_data[10][700:800])
plt.savefig("raw_data.png")

# %%
len(raw_data[0][1016:])
# Out:
# 1016

# %%
count = 0
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        count += 1
count
# Out:
# 654

# %%
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        raw_data[i] = raw_data[i][1016:]

# %%
count = 0
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        count += 1
count
# Out:
# 0

# %%
raw_data = pd.DataFrame(raw_data)

# %%
plt.figure(figsize=(30, 10))

for i in range(30):
    # 투명도 0.5로 그래프 그리기
    # matplotlib의 plot 함수를 사용
    plt.plot(raw_data.iloc[i][730:800], alpha=0.5)
plt.show()

# %%
abs_normalized_data = raw_data.abs()
abs_normalized_data = abs_normalized_data.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)
abs_normalized_data.iloc[201][700:800].plot()
# Out:
# <Axes: >

# %%
abs_normalized_data.to_csv("experiment_1/empty.csv")

# %%
# 길이가 1000이상인, 큰 데이터만 가져오기
data = open("20240705-175445_DecaWaveAllAccum.log", "r")
data_log = []
i = 0

for line in data:
    if len(line) > 1000:
        data_log.append(line)

# %%
len(data_log)
# Out:
# 2701

# %%
data_log[2][:132]  # 없애야할 부분
# Out:
# 'RX E\x00 WInd(0735), PSC(0770), CE(0000), RSE(0000), HE(0000), STO(0001), FFE(0000), T(7EB4), RSL(-090.6144), FSL(-091.9548), RSMPL(38)'

# %%
processed_data = []

# 데이터 순회
for i in data_log:
    # 알파벳이 포함된 경우
    if any(c.isalpha() for c in i):
        # "RSMPL(01)" 문자열의 위치 찾기
        index = i.find("RSMPL")
        # 해당 위치가 유효한 경우
        if index != -1:
            # "RSMPL(01)"까지의 문자열 제거
            i = i[index + len("RSMPL")+4:]
            processed_data.append(i)
        else:
            # "RSMPL(01)" 문자열이 없는 경우, 원본 데이터 추가
            processed_data.append(i)
    else:
        # 알파벳이 없는 경우, 원본 데이터 추가
        processed_data.append(i)

# 처리된 데이터 넣기
data_log = processed_data
raw_data = []

for i in range(len(data_log)):
    data_sample = [int(x) for x in data_log[i].strip().split(",") if x]
    raw_data.append(data_sample)

# %%
len(raw_data[0])
for i in range(10):
    print(len(raw_data[i]))
# Out:
# 1016
# 1016
# 1016
# 2032
# 1016
# 1016
# 1016
# 2032
# 1016
# 2032

# %%
count = 0
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        count += 1
count
# Out:
# 539

# %%
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        raw_data[i] = raw_data[i][1016:]

# %%
count = 0
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        count += 1
count
# Out:
# 0

# %%
raw_data = pd.DataFrame(raw_data)

# %%
plt.figure(figsize=(30, 10))

for i in range(30):
    # 투명도 0.5로 그래프 그리기
    # matplotlib의 plot 함수를 사용
    plt.plot(raw_data.iloc[i][730:800], alpha=0.5)
plt.show()

# %%
abs_normalized_data = raw_data.abs()
abs_normalized_data = abs_normalized_data.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)
abs_normalized_data.iloc[204][700:800].plot()
# Out:
# <AxesSubplot:>

# %%
abs_normalized_data.to_csv("experiment_1/angle_0_distance_10cm.csv")

# %% [markdown]
# ## data split

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Embedding
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
# Out:
# WARNING:tensorflow:From c:\Users\stand\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
empty = pd.read_csv("experiment_1/empty.csv", index_col=0)
print(empty.shape)
empty.head()
# Out:
# (3540, 1016)
#           0         1         2         3         4         5         6  \
# 0  0.003769  0.000547  0.000122  0.000547  0.004681  0.006869  0.011002
# 1  0.005473  0.004440  0.008089  0.007298  0.004744  0.000487  0.004196
# 2  0.330806  0.229497  0.123363  0.393522  0.561682  0.729152  0.559614
# 3  0.035697  0.027873  0.100244  0.107090  0.031296  0.087042  0.074817
# 4  0.005464  0.002489  0.012568  0.008014  0.006921  0.002064  0.012203
#
#           7         8         9  ...      1006      1007      1008      1009  \
# 0  0.009665  0.004255  0.008632  ...  0.003039  0.008085  0.005896  0.000061
# 1  0.007298  0.002129  0.013015  ...  0.006142  0.000182  0.002980  0.008575
# 2  0.272915  0.452791  0.643005  ...  0.582357  0.197795  0.578222  0.670572
# 3  0.054279  0.000978  0.043032  ...  0.087531  0.030807  0.002445  0.042543
# 4  0.010989  0.008257  0.000971  ...  0.003825  0.003157  0.000364  0.002793
#
#        1010      1011      1012      1013      1014      1015
# 0  0.007294  0.004620  0.004741  0.018844  0.004377  0.005532
# 1  0.006994  0.002372  0.005778  0.003223  0.006568  0.013075
# 2  0.521709  0.526533  0.577533  0.546520  0.638181  0.569263
# 3  0.001467  0.097800  0.052323  0.030807  0.005868  0.033252
# 4  0.011475  0.003764  0.000546  0.005889  0.005889  0.003218
#
# [5 rows x 1016 columns]

# %%
a0d10 = pd.read_csv("experiment_1/angle_0_distance_10cm.csv", index_col=0)
print(a0d10.shape)
a0d10.head()
# Out:
# (2701, 1016)
#           0         1         2         3         4         5         6  \
# 0  0.011921  0.018521  0.036907  0.026266  0.012998  0.006331  0.003165
# 1  0.011685  0.010041  0.005051  0.012171  0.018622  0.005295  0.009372
# 2  0.573034  0.537079  0.322846  0.363296  0.522846  0.356554  0.402247
# 3  0.010970  0.002377  0.021086  0.007252  0.001828  0.014260  0.013346
# 4  0.029327  0.023172  0.028421  0.024258  0.023353  0.017741  0.013034
#
#           7         8         9  ...      1006      1007      1008      1009  \
# 0  0.005051  0.023572  0.039130  ...  0.021417  0.021888  0.007947  0.009564
# 1  0.023552  0.015944  0.003895  ...  0.012293  0.016614  0.007729  0.000609
# 2  0.504869  0.381273  0.415730  ...  0.495131  0.335581  0.395506  0.425468
# 3  0.004632  0.027972  0.029130  ...  0.002438  0.006399  0.012981  0.008837
# 4  0.004435  0.004164  0.004435  ...  0.033762  0.026702  0.020366  0.028421
#
#        1010      1011      1012      1013      1014      1015
# 0  0.031587  0.024515  0.009496  0.013470  0.011180  0.012460
# 1  0.003225  0.003165  0.002860  0.013206  0.027325  0.025438
# 2  0.435955  0.507865  0.622472  0.794757  0.477154  0.257678
# 3  0.006094  0.001767  0.003291  0.000244  0.002316  0.016272
# 4  0.025706  0.027516  0.010500  0.012944  0.014120  0.011043
#
# [5 rows x 1016 columns]

# %%
label = [0]*3540 + [1]*2701
len(label)
# Out:
# 6241

# %%
label[3536:3545]  # 잘 되어있나 확인
# Out:
# [0, 0, 0, 0, 1, 1, 1, 1, 1]

# %%
label = pd.DataFrame(label)

# %%
train = pd.concat([empty, a0d10], ignore_index=True)
train.shape
# Out:
# (6241, 1016)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train, label, test_size=0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (4992, 1016)
# (1249, 1016)
# (4992, 1)
# (1249, 1)

# %% [markdown]
# ## model

# %%
# !nvidia-smi
# Out:
# Sun Jul  7 01:14:03 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.49       Driver Version: 528.49       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   42C    P8    13W / 170W |   1454MiB / 12288MiB |     10%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3956    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A      9928    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     10568    C+G   ...n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A     10860    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     12932    C+G   ...perience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     13204    C+G   ...perience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     13864    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     15272    C+G   ...e\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     16364    C+G   ...oft\OneDrive\OneDrive.exe    N/A      |
# |    0   N/A  N/A     16596    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     17324    C+G   ...ge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     17716    C+G   ...in7x64\steamwebhelper.exe    N/A      |
# |    0   N/A  N/A     17952    C+G   ...in7x64\steamwebhelper.exe    N/A      |
# |    0   N/A  N/A     18048    C+G   ...tqa\iCloud\iCloudHome.exe    N/A      |
# |    0   N/A  N/A     19892    C+G   ...592.87\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     19940    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     20304    C+G   ...592.87\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     20556    C+G   ...8wekyb3d8bbwe\GameBar.exe    N/A      |
# |    0   N/A  N/A     20596    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     22980    C+G   ...n\Quick Menu\CNQMMAIN.EXE    N/A      |
# |    0   N/A  N/A     29880    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
import sys
print("tensorflow: ", tf.__version__)
print("python: ",sys.version)
# Out:
# tensorflow:  2.15.0
# python:  3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]

# %% [markdown]
# ### multi GPU 사용하기

# %%
# 확인
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9064629771692504565
#  xla_global_id: -1]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

# %%
mirrored_strategy = tf.distribute.MirroredStrategy()
# Out:
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
# 입력 데이터에 채널 차원 추가 (Conv1D를 위해)
X_train = np.expand_dims(X_train, axis=-1) # 채널 차원 추가
print(X_train.shape)
X_test = np.expand_dims(X_test, axis=-1)
print(X_test.shape)
# Out:
# (4992, 1016, 1)
# (1249, 1016, 1)

# %%
model = models.Sequential()
model.add(layers.Conv1D(10, 4, activation='relu', input_shape=(1016,1)))
model.add(layers.Conv1D(20, 5, activation='relu'))
model.add(layers.MaxPool1D(2, 2))
model.add(layers.Flatten())
model.add(layers.Dense(1, activation='sigmoid')) # 이진 분류를 위해 sigmoid사용함
model.summary()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\stand\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\stand\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1013, 10)          50
#
#  conv1d_1 (Conv1D)           (None, 1009, 20)          1020
#
#  max_pooling1d (MaxPooling1  (None, 504, 20)           0
#  D)
#
#  flatten (Flatten)           (None, 10080)             0
#
#  dense (Dense)               (None, 1)                 10081
#
# =================================================================
# Total params: 11151 (43.56 KB)
# Trainable params: 11151 (43.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:From c:\Users\stand\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
with mirrored_strategy.scope():
    model = models.Sequential()
    model.add(layers.Conv1D(10, 4, activation='relu', input_shape=(1016,1)))
    model.add(layers.Conv1D(20, 5, activation='relu'))
    model.add(layers.MaxPool1D(2, 2))
    model.add(layers.Flatten())
    model.add(layers.Dense(1, activation='sigmoid')) # 이진 분류를 위해 sigmoid사용함
    model.summary()
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 1013, 10)          50
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 1009, 20)          1020
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 504, 20)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10080)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 10081
# =================================================================
# Total params: 11,151
# Trainable params: 11,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 학습
history = model.fit(X_train, Y_train, epochs=50, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\stand\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\stand\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 156/156 [==============================] - 2s 6ms/step - loss: 0.4214 - accuracy: 0.8003 - val_loss: 0.3257 - val_accuracy: 0.8575
# Epoch 2/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.3103 - accuracy: 0.8530 - val_loss: 0.2944 - val_accuracy: 0.8503
# Epoch 3/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.2809 - accuracy: 0.8658 - val_loss: 0.2637 - val_accuracy: 0.8655
# Epoch 4/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.2506 - accuracy: 0.8836 - val_loss: 0.2580 - val_accuracy: 0.8711
# Epoch 5/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.2368 - accuracy: 0.8912 - val_loss: 0.2501 - val_accuracy: 0.8911
# Epoch 6/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.2117 - accuracy: 0.9139 - val_loss: 0.2967 - val_accuracy: 0.9031
# Epoch 7/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.2008 - accuracy: 0.9189 - val_loss: 0.2860 - val_accuracy: 0.8959
# Epoch 8/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.1719 - accuracy: 0.9375 - val_loss: 0.2371 - val_accuracy: 0.9119
# Epoch 9/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.1494 - accuracy: 0.9497 - val_loss: 0.2464 - val_accuracy: 0.9207
# Epoch 10/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.1397 - accuracy: 0.9551 - val_loss: 0.2308 - val_accuracy: 0.9303
# Epoch 11/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.1247 - accuracy: 0.9623 - val_loss: 0.2433 - val_accuracy: 0.9376
# Epoch 12/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.1203 - accuracy: 0.9651 - val_loss: 0.2364 - val_accuracy: 0.9335
# Epoch 13/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0940 - accuracy: 0.9726 - val_loss: 0.2150 - val_accuracy: 0.9408
# Epoch 14/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0857 - accuracy: 0.9762 - val_loss: 0.2498 - val_accuracy: 0.9351
# Epoch 15/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.0776 - accuracy: 0.9792 - val_loss: 0.2388 - val_accuracy: 0.9408
# Epoch 16/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0714 - accuracy: 0.9816 - val_loss: 0.2337 - val_accuracy: 0.9424
# Epoch 17/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0653 - accuracy: 0.9832 - val_loss: 0.2291 - val_accuracy: 0.9432
# Epoch 18/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.0590 - accuracy: 0.9864 - val_loss: 0.2406 - val_accuracy: 0.9376
# Epoch 19/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0549 - accuracy: 0.9880 - val_loss: 0.2332 - val_accuracy: 0.9464
# Epoch 20/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0540 - accuracy: 0.9876 - val_loss: 0.2607 - val_accuracy: 0.9456
# Epoch 21/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0505 - accuracy: 0.9878 - val_loss: 0.2383 - val_accuracy: 0.9440
# Epoch 22/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0480 - accuracy: 0.9896 - val_loss: 0.2426 - val_accuracy: 0.9448
# Epoch 23/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0442 - accuracy: 0.9920 - val_loss: 0.2428 - val_accuracy: 0.9488
# Epoch 24/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0417 - accuracy: 0.9930 - val_loss: 0.2538 - val_accuracy: 0.9432
# Epoch 25/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.0402 - accuracy: 0.9930 - val_loss: 0.2556 - val_accuracy: 0.9504
# Epoch 26/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0396 - accuracy: 0.9932 - val_loss: 0.2689 - val_accuracy: 0.9480
# Epoch 27/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0367 - accuracy: 0.9940 - val_loss: 0.2584 - val_accuracy: 0.9424
# Epoch 28/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0439 - accuracy: 0.9898 - val_loss: 0.2662 - val_accuracy: 0.9416
# Epoch 29/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0341 - accuracy: 0.9946 - val_loss: 0.2839 - val_accuracy: 0.9408
# Epoch 30/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0357 - accuracy: 0.9924 - val_loss: 0.2799 - val_accuracy: 0.9432
# Epoch 31/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0325 - accuracy: 0.9942 - val_loss: 0.2781 - val_accuracy: 0.9464
# Epoch 32/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0282 - accuracy: 0.9958 - val_loss: 0.2869 - val_accuracy: 0.9440
# Epoch 33/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0287 - accuracy: 0.9954 - val_loss: 0.2992 - val_accuracy: 0.9424
# Epoch 34/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0263 - accuracy: 0.9948 - val_loss: 0.3003 - val_accuracy: 0.9440
# Epoch 35/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.0270 - accuracy: 0.9956 - val_loss: 0.3051 - val_accuracy: 0.9392
# Epoch 36/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.0322 - accuracy: 0.9938 - val_loss: 0.2958 - val_accuracy: 0.9440
# Epoch 37/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0251 - accuracy: 0.9954 - val_loss: 0.3085 - val_accuracy: 0.9408
# Epoch 38/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0213 - accuracy: 0.9968 - val_loss: 0.3257 - val_accuracy: 0.9392
# Epoch 39/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0217 - accuracy: 0.9962 - val_loss: 0.3386 - val_accuracy: 0.9448
# Epoch 40/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0201 - accuracy: 0.9968 - val_loss: 0.3208 - val_accuracy: 0.9432
# Epoch 41/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.0175 - accuracy: 0.9974 - val_loss: 0.3247 - val_accuracy: 0.9400
# Epoch 42/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0201 - accuracy: 0.9952 - val_loss: 0.3396 - val_accuracy: 0.9464
# Epoch 43/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.0195 - accuracy: 0.9964 - val_loss: 0.3433 - val_accuracy: 0.9440
# Epoch 44/50
# 156/156 [==============================] - 1s 5ms/step - loss: 0.0238 - accuracy: 0.9938 - val_loss: 0.3442 - val_accuracy: 0.9440
# Epoch 45/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0235 - accuracy: 0.9934 - val_loss: 0.3448 - val_accuracy: 0.9408
# Epoch 46/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0174 - accuracy: 0.9970 - val_loss: 0.3446 - val_accuracy: 0.9448
# Epoch 47/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0143 - accuracy: 0.9978 - val_loss: 0.3498 - val_accuracy: 0.9424
# Epoch 48/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0159 - accuracy: 0.9964 - val_loss: 0.3612 - val_accuracy: 0.9448
# Epoch 49/50
# 156/156 [==============================] - 1s 4ms/step - loss: 0.0121 - accuracy: 0.9980 - val_loss: 0.3659 - val_accuracy: 0.9448
# Epoch 50/50
# 156/156 [==============================] - 1s 6ms/step - loss: 0.0102 - accuracy: 0.9980 - val_loss: 0.3676 - val_accuracy: 0.9472

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(X_test,  Y_test, verbose=2)
# Out:
# 40/40 - 0s - loss: 0.3676 - accuracy: 0.9472 - 96ms/epoch - 2ms/step

# %%
print(test_acc)
# Out:
# 0.9471577405929565
