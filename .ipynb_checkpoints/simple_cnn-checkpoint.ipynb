# %% [markdown]
# # 데이터 불러오기

# %%
# 끝자리가 7로 끝나는 데이터만 가져오기
data = open("20240705-171717_DecaWaveAllAccum.log", "r")
data_log = []
i = 0

for line in data:
    if len(line) > 1000:
        data_log.append(line)

# %%
len(data_log)
# Out:
# 3540

# %%
data_log[0][:132]  # 없애야할 부분
# Out:
# 'RX E\x00 WInd(0735), PSC(0449), CE(0000), RSE(0000), HE(0000), STO(0001), FFE(0000), T(7EB4), RSL(-085.1200), FSL(-086.2409), RSMPL(01)'

# %%
processed_data = []

# 데이터 순회
for i in data_log:
    # 알파벳이 포함된 경우
    if any(c.isalpha() for c in i):
        # "RSMPL(01)" 문자열의 위치 찾기
        index = i.find("RSMPL")
        # 해당 위치가 유효한 경우
        if index != -1:
            # "RSMPL(01)"까지의 문자열 제거
            i = i[index + len("RSMPL")+4:]
            processed_data.append(i)
        else:
            # "RSMPL(01)" 문자열이 없는 경우, 원본 데이터 추가
            processed_data.append(i)
    else:
        # 알파벳이 없는 경우, 원본 데이터 추가
        processed_data.append(i)

# 처리된 데이터 출력

# %%
data_log = processed_data
raw_data = []

for i in range(len(data_log)):
    data_sample = [int(x) for x in data_log[i].strip().split(",") if x]
    raw_data.append(data_sample)

# %%
len(raw_data[0])
for i in range(10):
    print(len(raw_data[i]))
# Out:
# 2032
# 1016
# 1016
# 2032
# 1016
# 2032
# 1016
# 1016
# 1016
# 1016

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.clf()
plt.plot(raw_data[10][700:800])
plt.savefig("raw_data.png")

# %%
len(raw_data[0][1016:])
# Out:
# 1016

# %%
count = 0
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        count += 1
count
# Out:
# 654

# %%
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        raw_data[i] = raw_data[i][1016:]

# %%
count = 0
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        count += 1
count
# Out:
# 0

# %%
raw_data = pd.DataFrame(raw_data)

# %%
plt.figure(figsize=(30, 10))

for i in range(30):
    # 투명도 0.5로 그래프 그리기
    # matplotlib의 plot 함수를 사용
    plt.plot(raw_data.iloc[i][730:800], alpha=0.5)
plt.show()

# %%
abs_normalized_data = raw_data.abs()
abs_normalized_data = abs_normalized_data.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)
abs_normalized_data.iloc[201][700:800].plot()
# Out:
# <AxesSubplot:>

# %%
abs_normalized_data.to_csv("experiment_1/empty.csv")

# %%
# 길이가 1000이상인, 큰 데이터만 가져오기
data = open("20240705-175445_DecaWaveAllAccum.log", "r")
data_log = []
i = 0

for line in data:
    if len(line) > 1000:
        data_log.append(line)

# %%
len(data_log)
# Out:
# 2701

# %%
data_log[2][:132]  # 없애야할 부분
# Out:
# 'RX E\x00 WInd(0735), PSC(0770), CE(0000), RSE(0000), HE(0000), STO(0001), FFE(0000), T(7EB4), RSL(-090.6144), FSL(-091.9548), RSMPL(38)'

# %%
processed_data = []

# 데이터 순회
for i in data_log:
    # 알파벳이 포함된 경우
    if any(c.isalpha() for c in i):
        # "RSMPL(01)" 문자열의 위치 찾기
        index = i.find("RSMPL")
        # 해당 위치가 유효한 경우
        if index != -1:
            # "RSMPL(01)"까지의 문자열 제거
            i = i[index + len("RSMPL")+4:]
            processed_data.append(i)
        else:
            # "RSMPL(01)" 문자열이 없는 경우, 원본 데이터 추가
            processed_data.append(i)
    else:
        # 알파벳이 없는 경우, 원본 데이터 추가
        processed_data.append(i)

# 처리된 데이터 넣기
data_log = processed_data
raw_data = []

for i in range(len(data_log)):
    data_sample = [int(x) for x in data_log[i].strip().split(",") if x]
    raw_data.append(data_sample)

# %%
len(raw_data[0])
for i in range(10):
    print(len(raw_data[i]))
# Out:
# 1016
# 1016
# 1016
# 2032
# 1016
# 1016
# 1016
# 2032
# 1016
# 2032

# %%
count = 0
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        count += 1
count
# Out:
# 539

# %%
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        raw_data[i] = raw_data[i][1016:]

# %%
count = 0
for i in range(len(raw_data)):
    if len(raw_data[i]) > 1016:
        count += 1
count
# Out:
# 0

# %%
raw_data = pd.DataFrame(raw_data)

# %%
plt.figure(figsize=(30, 10))

for i in range(30):
    # 투명도 0.5로 그래프 그리기
    # matplotlib의 plot 함수를 사용
    plt.plot(raw_data.iloc[i][730:800], alpha=0.5)
plt.show()

# %%
abs_normalized_data = raw_data.abs()
abs_normalized_data = abs_normalized_data.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)
abs_normalized_data.iloc[204][700:800].plot()
# Out:
# <AxesSubplot:>

# %%
abs_normalized_data.to_csv("experiment_1/angle_0_distance_10cm.csv")

# %% [markdown]
# ## data split

# %%
import tensorflow

from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Embedding
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
empty = pd.read_csv("experiment_1/empty.csv", index_col=0)
print(empty.shape)
empty.head()
# Out:
# (3540, 1016)
#           0         1         2         3         4         5         6  \
# 0  0.003769  0.000547  0.000122  0.000547  0.004681  0.006869  0.011002
# 1  0.005473  0.004440  0.008089  0.007298  0.004744  0.000487  0.004196
# 2  0.330806  0.229497  0.123363  0.393522  0.561682  0.729152  0.559614
# 3  0.035697  0.027873  0.100244  0.107090  0.031296  0.087042  0.074817
# 4  0.005464  0.002489  0.012568  0.008014  0.006921  0.002064  0.012203
#
#           7         8         9  ...      1006      1007      1008      1009  \
# 0  0.009665  0.004255  0.008632  ...  0.003039  0.008085  0.005896  0.000061
# 1  0.007298  0.002129  0.013015  ...  0.006142  0.000182  0.002980  0.008575
# 2  0.272915  0.452791  0.643005  ...  0.582357  0.197795  0.578222  0.670572
# 3  0.054279  0.000978  0.043032  ...  0.087531  0.030807  0.002445  0.042543
# 4  0.010989  0.008257  0.000971  ...  0.003825  0.003157  0.000364  0.002793
#
#        1010      1011      1012      1013      1014      1015
# 0  0.007294  0.004620  0.004741  0.018844  0.004377  0.005532
# 1  0.006994  0.002372  0.005778  0.003223  0.006568  0.013075
# 2  0.521709  0.526533  0.577533  0.546520  0.638181  0.569263
# 3  0.001467  0.097800  0.052323  0.030807  0.005868  0.033252
# 4  0.011475  0.003764  0.000546  0.005889  0.005889  0.003218
#
# [5 rows x 1016 columns]

# %%
a0d10 = pd.read_csv("experiment_1/angle_0_distance_10cm.csv", index_col=0)
print(a0d10.shape)
a0d10.head()
# Out:
# (2701, 1016)
#           0         1         2         3         4         5         6  \
# 0  0.011921  0.018521  0.036907  0.026266  0.012998  0.006331  0.003165
# 1  0.011685  0.010041  0.005051  0.012171  0.018622  0.005295  0.009372
# 2  0.573034  0.537079  0.322846  0.363296  0.522846  0.356554  0.402247
# 3  0.010970  0.002377  0.021086  0.007252  0.001828  0.014260  0.013346
# 4  0.029327  0.023172  0.028421  0.024258  0.023353  0.017741  0.013034
#
#           7         8         9  ...      1006      1007      1008      1009  \
# 0  0.005051  0.023572  0.039130  ...  0.021417  0.021888  0.007947  0.009564
# 1  0.023552  0.015944  0.003895  ...  0.012293  0.016614  0.007729  0.000609
# 2  0.504869  0.381273  0.415730  ...  0.495131  0.335581  0.395506  0.425468
# 3  0.004632  0.027972  0.029130  ...  0.002438  0.006399  0.012981  0.008837
# 4  0.004435  0.004164  0.004435  ...  0.033762  0.026702  0.020366  0.028421
#
#        1010      1011      1012      1013      1014      1015
# 0  0.031587  0.024515  0.009496  0.013470  0.011180  0.012460
# 1  0.003225  0.003165  0.002860  0.013206  0.027325  0.025438
# 2  0.435955  0.507865  0.622472  0.794757  0.477154  0.257678
# 3  0.006094  0.001767  0.003291  0.000244  0.002316  0.016272
# 4  0.025706  0.027516  0.010500  0.012944  0.014120  0.011043
#
# [5 rows x 1016 columns]

# %%
label = [0]*3540 + [1]*2701
len(label)
# Out:
# 6241

# %%
label[3536:3545]  # 잘 되어있나 확인
# Out:
# [0, 0, 0, 0, 1, 1, 1, 1, 1]

# %%
label = pd.DataFrame(label)

# %%
train = pd.concat([empty, a0d10], ignore_index=True)
train.shape
# Out:
# (6241, 1016)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train, label, test_size=0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (4992, 1016)
# (1249, 1016)
# (4992, 1)
# (1249, 1)

# %% [markdown]
# ## model

# %%
# !nvidia-smi
# Out:
# Sat Jul  6 18:56:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     Off | 00000000:17:00.0 Off |                  N/A |
# |  0%   32C    P8              10W / 250W |  10724MiB / 11264MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce GTX 1080 Ti     Off | 00000000:65:00.0 Off |                  N/A |
# |  0%   27C    P8               8W / 250W |    506MiB / 11264MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   2621797      C   /home/icons/anaconda3/bin/python            252MiB |
# |    0   N/A  N/A   2621916      C   /home/icons/anaconda3/bin/python          10470MiB |
# |    1   N/A  N/A   2621797      C   /home/icons/anaconda3/bin/python            252MiB |
# |    1   N/A  N/A   2621916      C   /home/icons/anaconda3/bin/python            252MiB |
# +---------------------------------------------------------------------------------------+

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0'
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    tf.config.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)
# Out:
# Visible devices cannot be modified after being initialized

# %% [markdown]
# ### multi GPU 사용하기

# %%
# 확인
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14101576467873313232,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 10659889152
#  locality {
#    bus_id: 1
#    links {
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 7577192932291471858
#  physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:17:00.0, compute capability: 6.1",
#  name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 10658054144
#  locality {
#    bus_id: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 13295494360936113604
#  physical_device_desc: "device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:65:00.0, compute capability: 6.1"]

# %%
from core.yolov4 import YOLO, decode, compute_loss, decode_train
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-178-c30625c76f7a> in <module>
# ----> 1 from core.yolov4 import YOLO, decode, compute_loss, decode_train
#
# ModuleNotFoundError: No module named 'core'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-170-10f4bc5d21f4> in <module>
# ----> 1 tf.config.experimental.set_memory_growth(gpus[0], True)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/config.py in set_memory_growth(device, enable)
#     659     RuntimeError: Runtime is already initialized.
#     660   """
# --> 661   context.context().set_memory_growth(device, enable)
#     662
#     663
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/context.py in set_memory_growth(self, dev, enable)
#    1478
#    1479     if self._context_handle is not None:
# -> 1480       raise RuntimeError(
#    1481           "Physical devices cannot be modified after being initialized")
#    1482
#
# RuntimeError: Physical devices cannot be modified after being initialized

# %%
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/GPU:0","/GPU:1"])
# Out:
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %%
# 입력 데이터에 채널 차원 추가 (Conv1D를 위해)
X_train = np.expand_dims(X_train, axis=-1) # 채널 차원 추가
print(X_train.shape)
X_test = np.expand_dims(X_test, axis=-1)
print(X_test.shape)
# Out:
# (4992, 1016, 1)
# (1249, 1016, 1)

# %%
with mirrored_strategy.scope():
    model = models.Sequential()
    model.add(layers.Conv1D(10, 4, activation='relu', input_shape=(1016,1)))
    model.add(layers.Conv1D(20, 5, activation='relu'))
    model.add(layers.MaxPool1D(2, 2))
    model.add(layers.Flatten())
    model.add(layers.Dense(1, activation='sigmoid')) # 이진 분류를 위해 sigmoid사용함
    model.summary()
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_19 (Conv1D)           (None, 1013, 10)          50
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 1009, 20)          1020
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 504, 20)           0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 10080)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 10081
# =================================================================
# Total params: 11,151
# Trainable params: 11,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 학습
history = model.fit(X_train, Y_train, epochs=50, validation_data=(X_test, Y_test), verbose=1)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-166-46c171e2f272> in <module>
#       1 # 모델 학습
# ----> 2 history = model.fit(X_train, Y_train, epochs=50, validation_data=(X_test, Y_test), verbose=1)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# UnknownError: 3 root error(s) found.
#   (0) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node sequential_13/conv1d_19/conv1d (defined at /threading.py:932) ]]
#   (1) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node sequential_13/conv1d_19/conv1d (defined at /threading.py:932) ]]
# 	 [[div_no_nan_1/ReadVariableOp_3/_16]]
#   (2) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node sequential_13/conv1d_19/conv1d (defined at /threading.py:932) ]]
# 	 [[update_0/AssignAddVariableOp/_43]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_18601]
#
# Function call stack:
# train_function -> train_function -> train_function
